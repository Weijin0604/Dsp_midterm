# %% [markdown]
# # 第三題

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import thinkdsp as tp
import thinkdsp
from scipy.signal import chirp, spectrogram

# %%
aUrl= 'https://query1.finance.yahoo.com/v7/finance/download/%5EGSPC?period1=-1325635200&period2=1588550400&interval=1d&events=history'
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df=pd.read_csv(aUrl)
a=df['Date'][1:6]
b=df['Date'][23188:23194]
print(a)
print(b)
# Out:
# 1    1928-01-03
# 2    1928-01-04
# 3    1928-01-05
# 4    1928-01-06
# 5    1928-01-09
# Name: Date, dtype: object
# 23188    2020-04-27
# 23189    2020-04-28
# 23190    2020-04-29
# 23191    2020-04-30
# 23192    2020-05-01
# Name: Date, dtype: object

# %%
df[['Date', 'Close']][1:23194].plot(kind = 'line', x = 'Date', y = 'Close',legend = False)
plt.show()

# %%
df[['Date', 'Close']][1:5000].plot(kind = 'line', x = 'Date', y = 'Close',legend = False)
plt.show()

# %% [markdown]
# # 第一題

# %%
class WJ():
    def evalute():
        t = np.linspace(0, 10, 5001)
        w = chirp(t, f0=6, f1=1, t1=10, method='linear')
        plt.plot(t, w)
        plt.title("Linear Chirp, f(0)=6, f(10)=1")
        plt.xlabel('t (sec)')
        plt.show()

# %%
t = np.linspace(0, 10, 5001)
w = chirp(t, f0=6, f1=1, t1=10, method='linear')
plt.plot(t, w)
plt.title("Linear Chirp, f(0)=6, f(10)=1")
plt.xlabel('t (sec)')
plt.show()

# %%
t = np.linspace(0, 10, 5001)
w = chirp(t, f0=0.22, f1=0.44, t1=10, method='linear')
plt.plot(t, w)
plt.title("Linear Chirp, f(0)=0.22, f(10)=0.44")
plt.xlabel('t (sec)')
plt.show()

# %% [markdown]
# # 第二題

# %% [markdown]
# ## 1

# %%
signal = thinkdsp.UncorrelatedUniformNoise()
x = signal.make_wave(duration=1, framerate=10000)

# %%
x.ys.shape
# Out:
# (10000,)

# %% [markdown]
# ## 2

# %%
from thinkdsp import UncorrelatedGaussianNoise

signal = UncorrelatedGaussianNoise()
x = signal.make_wave(duration=0.5, framerate=11025)
x.plot(linewidth=0.5)
x.ys.max(), x.ys.mean(), x.ys.std()
# Out:
# (3.288705850588036, 0.00420376168712534, 0.9924028024537274)

# %% [markdown]
# ## 3

# %%
spectrum = x.make_spectrum()
spectrum.plot_power(linewidth=1)

# %% [markdown]
# ## 4

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %% [markdown]
# ## 5

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %% [markdown]
# ## 6

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %% [markdown]
# ## 7

# %%
y= thinkdsp.UncorrelatedGaussianNoise()

# %%
x= thinkdsp.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)

y= x.cumsum()
x.ys.shape, y.ys.shape
y.plot()

# %% [markdown]
# ## 8

# %%
plt.plot(x.ts, x.ys)

# %% [markdown]
# ## 9

# %%
z= thinkdsp.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()

# %% [markdown]
# ## 10

# %%
z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-88b4994345c8> in <module>()
# ----> 1 z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
#       2 z.plot()
#
# NameError: name 'td' is not defined

# %%
z.make_spectrum().make_integrated_spectrum().estimate_slope()
